# %% [markdown]
# #  Back Propagation

# %% [markdown]
# > [x1= 0, x2 = 1, t = 1] : Row 2
#
# + Forward Propagation :
#
#     Net 3 = 0.0956    >>Acttivation function>>  O3 = 0.523881
#
#     Net 4 = - 0.0978  >>Acttivation function>>  O4 = 0.524430
#
#     Net 5 = 0.438029  >>Acttivation function>>  y = 0.607789
#
# + Error :
#     Err_p2 = 0.076914
#
# + Back Propagation :
#
#     - Finding Delta Pattern 2 :
#
#         Delta 5 = 0.093495
#
#         Delta 3 = 0.008763
#
#         Delta 4 = 0.005074
#
#     - Finding neu Weights Pattern 2 :
#
#         w3,5 = 0.3
#
#         w4,5 = - 0.2
#
#         wb2,5 = 0.3
#
#         w1,4 = - 0.2
#
#         w2,4 = 0.2
#
#         wb1,4 = - 0.2
#
#         w1,3 = 0.3
#
#         w2,3 = 0.097
#
#         wb1,3 = 0.1

# %% [markdown]
# > Row 3 : [x1 = 1, x2 = 0, t = 1] :
#
# + Forward Propagation :
#
#     Net 3 = 0.498
#
#     O3 = 0.6219
#
#     Net 4 = - 0.496
#
#     O4 = 0.621518
#
#     Net 5 = 0.450430
#
#     y = 0.610741
#
# + Error:
#
#     Err_p3 = 0.075761
#
# + Back propagation :
#     - Finding Delta Pattern 3 :
#
#         Delta 5 = 0.092541
#
#         Delta 3 = 0.008486
#
#         Delta 4 = - 0.004440
#
#     - Finding neu Weights Pattern 3 :
#
#         w1,4 = - 0.2
#
#         w2,4 = 0.1
#
#         wb1,4 = - 0.2
#
#         w3,5 = 0.4
#
#         w4,5 = - 0.1
#
#         wb2,5 = 0.4
#
#         w1,3 = 0.3
#
#         w2,3 = - 0.094
#
#         wb1,3 = 0.2

# %% [markdown]
# > Row 4 : [x1 = 1, x2 = 1, t = 0] :
#
# + Forward Propagation Pattern 4 :
#
#     Net 3 = 0.406
#
#     O3 = 0.600128
#
#     Net 4 = - 0.201
#
#     O4 = 0.550081
#
#     Net 5 = 0.547736
#
#     y = 0.633610
#
# + Error :
#
#     Err_p4 = 0.200730
#
# + Back propagation :
#
#     - Finding Delta Pattern 4 :
#
#         Delta 5 = - 0.147
#
#         Delta 3 = - 0.0141
#
#         Delta 4 = 0.006
#
#     - Finding neu Weights Pattern 4 :
#
#         w3,5 = 0.4
#
#         w4,5 = - 0.2
#
#         wb2,5 = 0.3
#
#         w1,4 = - 0.1
#
#         w2,4 = 0.2
#
#         wb1,4 = - 0.1
#
#         w1,3 = 0.2
#
#         w2,3 = - 0.098
#
#         wb1,3 = 0.1
#
# + Total Error = 0.1988 + 0.076914 + 0.075761 + 0.200730 = 0.552205 .
#
# End of Epoch 1
